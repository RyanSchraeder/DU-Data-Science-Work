# %%
# %matplotlib notebook
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data_file = pd.read_csv(city_data_to_load)
ride_data_file = pd.read_csv(ride_data_to_load)

# Combine the data into a single dataset
master_sheet_pyber = pd.merge(city_data_file, ride_data_file, how='outer', on='city')
master_sheet_pyber.sort_values('fare', ascending="False")

# Display the data table for preview
master_sheet_pyber.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
# Create a better sheet to condense data used to visualize requested data 
plot_data_file = "../Resources/Driver Data Per City.csv"

# rows are truncated, so write to a new .csv to read in excel. Use to_csv
#plot_data.to_csv(r"../Driver Data Per City.csv")

# Plot Data has since been overwritten. Import CSV 
plot_data = pd.read_csv(plot_data_file)
plot_data
# Out:
#                     city      type  Total Rides  Average Fare  Driver Count
# 0               Liumouth     Urban           33     26.150000          2277
# 1     South Michelleport     Urban           31     24.451613          2232
# 2           West Anthony     Urban           30     24.736667          2100
# 3                Royland     Urban           30     20.570667          1920
# 4        East Kaylahaven     Urban           29     23.757931          1885
# 5            West Angela     Urban           39     25.990000          1872
# 6       West Samuelburgh     Urban           25     21.767600          1825
# 7               Jerryton     Urban           25     25.649200          1600
# 8            Grahamburgh     Urban           25     25.221200          1525
# 9     Port Samanthamouth     Urban           25     25.642800          1425
# 10           Carriemouth     Urban           27     28.314444          1404
# 11         Lake Scottton     Urban           24     23.809167          1392
# 12          Williamsstad     Urban           23     24.362174          1357
# 13          West Gabriel     Urban           23     20.346087          1311
# 14           Port Angela     Urban           19     23.836842          1273
# 15          Reynoldsfurt     Urban           19     21.919474          1273
# 16             Pattyland     Urban           21     23.980476          1239
# 17           West Robert     Urban           31     25.123871          1209
# 18         South Phillip     Urban           31     28.571290          1178
# 19            Justinberg     Urban           30     23.694333          1170
# 20       West Josephberg     Urban           26     21.720385          1170
# 21           Roberthaven     Urban           24     23.729167          1128
# 22       Christopherfurt     Urban           27     24.501852          1107
# 23           Richardfort     Urban           28     22.373214          1064
# 24           Hurleymouth     Urban           28     25.891429          1008
# 25   New Kimberlyborough     Urban           30     22.589000           990
# 26         North Jasmine     Urban           30     25.205333           990
# 27          Valentineton     Urban           22     24.636364           990
# 28          Joneschester     Urban           25     22.289600           975
# 29         New Paulville     Urban           22     21.675909           968
# ..                   ...       ...          ...           ...           ...
# 90            Port Shane  Suburban           19     31.077895           133
# 91             Sotoville  Suburban           11     31.980000           110
# 92         North Timothy  Suburban           15     31.262000           105
# 93       Lake Robertside  Suburban           25     31.262000           100
# 94         West Kimmouth  Suburban           20     29.871500            80
# 95             Lewisland  Suburban           17     34.614118            68
# 96        East Aaronbury  Suburban            9     25.661111            63
# 97              Lake Ann  Suburban           12     30.890000            36
# 98             Grayville  Suburban           15     27.763333            30
# 99       Williamsonville  Suburban           14     31.875000            28
# 100         South Brenda  Suburban           24     33.964583            24
# 101   North Richardhaven  Suburban           14     24.704286            14
# 102          Michaelberg     Rural           12     34.997500            72
# 103          North Holly     Rural            9     29.130000            72
# 104         Bradshawfurt     Rural           10     40.064000            70
# 105       South Jennifer     Rural            7     35.264286            49
# 106       Randallchester     Rural            5     29.742000            45
# 107         West Heather     Rural            9     33.890000            36
# 108          Penaborough     Rural            5     35.246000            30
# 109      South Saramouth     Rural            4     36.160000            28
# 110       Harringtonfort     Rural            6     33.470000            24
# 111           Lake Jamie     Rural            6     34.358333            24
# 112      Lake Latoyabury     Rural           11     26.061818            22
# 113            Garzaport     Rural            3     24.123333            21
# 114         New Ryantown     Rural            6     43.278333            12
# 115          North Jaime     Rural            8     30.802500             8
# 116    South Marychester     Rural            8     41.870000             8
# 117          Jessicaport     Rural            6     36.013333             6
# 118          Taylorhaven     Rural            6     42.263333             6
# 119           Newtonview     Rural            4     36.745000             4
#
# [120 rows x 5 columns]

# %%
# Split into categories for each color in the scatter plot 

total_rides_per_city = plot_data['Total Rides']
avg_fare_per_city = plot_data ['Average Fare']

#number of Drivers per type, city 
city_df_urban = city_data_file.loc[city_data_file["type"]=="Urban"]
city_df_suburban = city_data_file.loc[city_data_file["type"]=="Suburban"]
city_df_rural = city_data_file.loc[city_data_file["type"]=="Rural"]

#Sum of drivers per city 
##UPDATE ALL VARS TO REFLECT DEFINED VARS IN NOTEBOOK

##URBAN
urban_ride_count = urban_cities.groupby(["city"]).count()["ride_id"]
urban_avg_fare = urban_cities.groupby(["city"]).mean()["fare"]
urban_driver_count = urban_cities.groupby(["city"]).mean()["driver_count"]

##SUBURBAN
suburban_ride_count = suburban_cities.groupby(["city"]).count()["ride_id"]
suburban_avg_fare = suburban_cities.groupby(["city"]).mean()["fare"]
suburban_driver_count = suburban_cities.groupby(["city"]).mean()["driver_count"]

##RURAL
rural_ride_count = rural_cities.groupby(["city"]).count()["ride_id"]
rural_avg_fare = rural_cities.groupby(["city"]).mean()["fare"]
rural_driver_count = rural_cities.groupby(["city"]).mean()["driver_count"]

plot_elements = pd.DataFrame({
    "Total Rides": total_rides_per_city,
    "Average Fare": avg_fare_per_city,
    "Driver Count Urban": city_df_urban_drivercount,
    "Driver Count Rural": city_df_rural_drivercount, 
    "Driver Count Suburban": city_df_suburban_drivercount
})


##DEFINE AXIS 
x_axis = np.arange(0, max(plot_elements['Total Rides']))
y_axis = np.arange (0, max(plot_elements['Average Fare']))
plt.xlim = (0, x_axis)
plt.ylim = (0, y_axis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-662af260b32e> in <module>
#      14
#      15 ##URBAN
# ---> 16 urban_ride_count = urban_cities.groupby(["city"]).count()["ride_id"]
#      17 urban_avg_fare = urban_cities.groupby(["city"]).mean()["fare"]
#      18 urban_driver_count = urban_cities.groupby(["city"]).mean()["driver_count"]
#
# NameError: name 'urban_cities' is not defined

# %%
# Build the scatter plots for each city types

plt.scatter(urban_ride_count, 
            urban_avg_fare, 
            s=10*urban_driver_count, c="coral", 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Urban")

plt.scatter(suburban_ride_count, 
            suburban_avg_fare, 
            s=10*suburban_driver_count, c="skyblue", 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Suburban")

plt.scatter(rural_ride_count, 
            rural_avg_fare, 
            s=10*rural_driver_count, c="gold", 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Rural")

# Incorporate the other graph properties

plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.text(17, 38
         , fontsize=8,
         s="Note: Circle size correlates with driver count per city")

plt.grid(axis='both', linewidth=.2, color = 'gray', linestyle='--')

# Create a legend 

plt.legend()

# Save Figure
# plt.savefig('../Images/Pyber Ride Sharing Data (2016).png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a7fb435d74a4> in <module>
#       1 # Build the scatter plots for each city types
#       2
# ----> 3 plt.scatter(urban_ride_count,
#       4             urban_avg_fare,
#       5             s=10*urban_driver_count, c="coral",
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Calculate Type Percents

city_type_percents = master_sheet_pyber.groupby('type')['fare'].sum()
city_type_df = pd.DataFrame(city_type_percents)
city_type_df


# Build Pie Chart

plt.title("% of Total Fares by City Type")
labels = ['Rural','Suburban','Urban']
sizes = city_type_df
colors = ["gold","lightskyblue","lightcoral"]
explode = [0, 0, 0.1]

plt.pie(sizes, labels=labels, colors=["gold","lightskyblue","lightcoral"], explode = explode, wedgeprops = {'linewidth': 3},
        autopct="%1.1f%%", shadow=True, startangle=140)

# Save Figure

# plt.savefig("../Images/% Total Fares Per City Type.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Calculate Ride Percents

ride_by_city_type = master_sheet_pyber.groupby('type')['ride_id'].count()
ride_by_city_type_df = pd.DataFrame(ride_by_city_type)
ride_by_city_type_df

# Build Pie Chart
plt.title("% of Total Rides by City Type")
labels = ['Rural','Suburban','Urban']
sizes = ride_by_city_type_df
colors = ["gold","lightskyblue","lightcoral"]
explode = [0, 0, 0.1]

plt.pie(sizes, labels=labels, colors=["gold","lightskyblue","lightcoral"], explode = explode, wedgeprops = {'linewidth': 3},
        autopct="%1.1f%%", shadow=True, startangle=140)

# Save Figure
#plt.savefig("../Images/% of Total Rides by City Type.png")
plt.show()

# %%
# Calculate Driver Percents

driver_percent_by_city = city_data_file.groupby ('type')['driver_count'].sum()

# Build Pie Charts

plt.title("% of Drivers by City Type")
labels = ['Rural','Suburban','Urban']
sizes = driver_percent_by_city
colors = ["gold","lightskyblue","lightcoral"]
explode = [0.0, 0.0, 0.1]

plt.pie(driver_percent_by_city, labels=labels, colors=["gold","lightskyblue","lightcoral"], explode=explode, 
        wedgeprops = {'linewidth': 3}, 
        autopct="%1.2f%%", shadow=True, 
        startangle=180, 
        radius= (1), 
        center=(0, 2)
    )
        
# Save Figure
#plt.savefig("../Images/% of Drivers by City Type.png")
plt.show()
