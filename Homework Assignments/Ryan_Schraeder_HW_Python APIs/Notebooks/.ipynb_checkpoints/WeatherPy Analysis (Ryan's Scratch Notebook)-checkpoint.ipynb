# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import json
import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

print(api_key)
# Out:
# 7a61e52ec7bd94ad476d93febca4b2d8

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %%
# Declare the querying URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = base_url +"appid="+ api_key + "&units="+ units +"&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=7a61e52ec7bd94ad476d93febca4b2d8&units=metric&q='

# %%
# Set City Count vars

citycount = 0
citycountfail = 0

# Create Lists for Each Column 

city_list = []         
cloudiness = []   
country = []      
date = []         
humidity = []    
lat = []          
lng = []          
MaxTemp = []      
WindSpeed = []  


for city in cities:

    citycount = citycount + 1
    
    print("Retrieving data for index " + str(citycount) + " " + city)
    
    try:
        weatherdetails = requests.get(query_url + city).json()
        city_list.append (weatherdetails["name"])
        cloudiness.append (weatherdetails["clouds"]["all"])
        country.append (weatherdetails["sys"]["country"])
        date.append (weatherdetails["dt"])
        humidity.append (weatherdetails["main"]["humidity"])
        lat.append (weatherdetails["coord"]["lat"])
        lng.append (weatherdetails["coord"]["lon"])
        MaxTemp.append (weatherdetails["main"]["temp_max"])
        WindSpeed.append (weatherdetails["wind"]["speed"])
        
    except:
        citycountfail = citycountfail + 1
        print("Error retrieving data for " + city)
        print("Error Code: " + str(weatherdetails ['cod']))
#        print("Message: " + weatherdetails['message'])

pprint(weatherdetails)        
print("Data Retrieval Complete....")
print("---------------------------------------------------------")
print("Number of cities weather data  not found: " + str(citycountfail))
# Out:
# Retrieving data for index 1 lebu
# Retrieving data for index 2 mar del plata
# Retrieving data for index 3 dikson
# Retrieving data for index 4 avarua
# Retrieving data for index 5 carnarvon
# Retrieving data for index 6 cape town
# Retrieving data for index 7 kruisfontein
# Retrieving data for index 8 yellowknife
# Retrieving data for index 9 hithadhoo
# Retrieving data for index 10 victoria
# Retrieving data for index 11 saint anthony
# Retrieving data for index 12 san patricio
# Retrieving data for index 13 rikitea
# Retrieving data for index 14 bonthe
# Retrieving data for index 15 ocean city
# Retrieving data for index 16 vaini
# Retrieving data for index 17 tarudant
# Error retrieving data for tarudant
# Error Code: 404
# Retrieving data for index 18 flinders
# Retrieving data for index 19 constitucion
# Retrieving data for index 20 clyde river
# Retrieving data for index 21 taolanaro
# Error retrieving data for taolanaro
# Error Code: 404
# Retrieving data for index 22 umm lajj
# Retrieving data for index 23 narsaq
# Retrieving data for index 24 concordia
# Retrieving data for index 25 hermanus
# Retrieving data for index 26 east london
# Retrieving data for index 27 nizhneyansk
# Error retrieving data for nizhneyansk
# Error Code: 404
# Retrieving data for index 28 isangel
# Retrieving data for index 29 thompson
# Retrieving data for index 30 lompoc
# Retrieving data for index 31 barranca
# Retrieving data for index 32 yarmouth
# Retrieving data for index 33 rawannawi
# Error retrieving data for rawannawi
# Error Code: 404
# Retrieving data for index 34 oktyabrskoye
# Retrieving data for index 35 zhuhai
# Retrieving data for index 36 mount isa
# Retrieving data for index 37 mataura
# Retrieving data for index 38 vaitupu
# Error retrieving data for vaitupu
# Error Code: 404
# Retrieving data for index 39 amarante
# Retrieving data for index 40 kavieng
# Retrieving data for index 41 coquimbo
# Retrieving data for index 42 buala
# Retrieving data for index 43 punta arenas
# Retrieving data for index 44 new norfolk
# Retrieving data for index 45 mahibadhoo
# Retrieving data for index 46 tsihombe
# Error retrieving data for tsihombe
# Error Code: 404
# Retrieving data for index 47 qujing
# Retrieving data for index 48 ulaangom
# Retrieving data for index 49 kawalu
# Retrieving data for index 50 priyutnoye
# Retrieving data for index 51 albany
# Retrieving data for index 52 sao joao da barra
# Retrieving data for index 53 ahipara
# Retrieving data for index 54 butaritari
# Retrieving data for index 55 belmonte
# Retrieving data for index 56 busselton
# Retrieving data for index 57 pisco
# Retrieving data for index 58 jamestown
# Retrieving data for index 59 tuktoyaktuk
# Retrieving data for index 60 kodiak
# Retrieving data for index 61 sao filipe
# Retrieving data for index 62 hokitika
# Retrieving data for index 63 vartej
# Retrieving data for index 64 manavgat
# Retrieving data for index 65 provideniya
# Retrieving data for index 66 ostrovnoy
# Retrieving data for index 67 san jeronimo
# Retrieving data for index 68 port augusta
# Retrieving data for index 69 illoqqortoormiut
# Error retrieving data for illoqqortoormiut
# Error Code: 404
# Retrieving data for index 70 bredasdorp
# Retrieving data for index 71 saryshagan
# Error retrieving data for saryshagan
# Error Code: 404
# Retrieving data for index 72 belushya guba
# Error retrieving data for belushya guba
# Error Code: 404
# Retrieving data for index 73 kapaa
# Retrieving data for index 74 miri
# Retrieving data for index 75 barbar
# Error retrieving data for barbar
# Error Code: 404
# Retrieving data for index 76 ushuaia
# Retrieving data for index 77 samalaeulu
# Error retrieving data for samalaeulu
# Error Code: 404
# Retrieving data for index 78 hilo
# Retrieving data for index 79 paredon
# Retrieving data for index 80 qaanaaq
# Retrieving data for index 81 dashitou
# Retrieving data for index 82 barrow
# Retrieving data for index 83 chimbote
# Retrieving data for index 84 talnakh
# Retrieving data for index 85 grindavik
# Retrieving data for index 86 sarkand
# Retrieving data for index 87 muroto
# Retrieving data for index 88 port alfred
# Retrieving data for index 89 bandarbeyla
# Retrieving data for index 90 brae
# Retrieving data for index 91 krasnyy chikoy
# Retrieving data for index 92 tasiilaq
# Retrieving data for index 93 diego de almagro
# Retrieving data for index 94 usakos
# Retrieving data for index 95 port elizabeth
# Retrieving data for index 96 maghama
# Error retrieving data for maghama
# Error Code: 404
# Retrieving data for index 97 trairi
# Retrieving data for index 98 gujrat
# Retrieving data for index 99 ilulissat
# Retrieving data for index 100 port lincoln
# Retrieving data for index 101 saint-philippe
# Retrieving data for index 102 northam
# Retrieving data for index 103 ampanihy
# Retrieving data for index 104 bastia
# Retrieving data for index 105 kahului
# Retrieving data for index 106 castro
# Retrieving data for index 107 ontario
# Retrieving data for index 108 sarangani
# Retrieving data for index 109 siuna
# Retrieving data for index 110 lavrentiya
# Retrieving data for index 111 codrington
# Retrieving data for index 112 roma
# Retrieving data for index 113 esperance
# Retrieving data for index 114 puerto escondido
# Retrieving data for index 115 bluff
# Retrieving data for index 116 chupa
# Retrieving data for index 117 georgetown
# Retrieving data for index 118 dombarovskiy
# Retrieving data for index 119 iqaluit
# Retrieving data for index 120 marsabit
# Retrieving data for index 121 grand river south east
# Error retrieving data for grand river south east
# Error Code: 404
# Retrieving data for index 122 hovd
# Retrieving data for index 123 kaniama
# Retrieving data for index 124 chagda
# Error retrieving data for chagda
# Error Code: 404
# Retrieving data for index 125 cidreira
# Retrieving data for index 126 ancud
# Retrieving data for index 127 bethel
# Retrieving data for index 128 mys shmidta
# Error retrieving data for mys shmidta
# Error Code: 404
# Retrieving data for index 129 nanortalik
# Retrieving data for index 130 dasoguz
# Retrieving data for index 131 aklavik
# Retrieving data for index 132 beloha
# Retrieving data for index 133 vlasotince
# Retrieving data for index 134 santa lucia
# Retrieving data for index 135 amazar
# Retrieving data for index 136 la ronge
# Retrieving data for index 137 pevek
# Retrieving data for index 138 saleaula
# Error retrieving data for saleaula
# Error Code: 404
# Retrieving data for index 139 hvammstangi
# Error retrieving data for hvammstangi
# Error Code: 404
# Retrieving data for index 140 sitka
# Retrieving data for index 141 masumbwe
# Retrieving data for index 142 pasighat
# Retrieving data for index 143 eshowe
# Retrieving data for index 144 rungata
# Error retrieving data for rungata
# Error Code: 404
# Retrieving data for index 145 airai
# Retrieving data for index 146 temple
# Retrieving data for index 147 shingu
# Retrieving data for index 148 ruatoria
# Error retrieving data for ruatoria
# Error Code: 404
# Retrieving data for index 149 gornyye klyuchi
# Retrieving data for index 150 pontal do parana
# Retrieving data for index 151 necochea
# Retrieving data for index 152 tumannyy
# Error retrieving data for tumannyy
# Error Code: 404
# Retrieving data for index 153 cherskiy
# Retrieving data for index 154 paso de los toros
# Retrieving data for index 155 nuuk
# Retrieving data for index 156 dalhousie
# Retrieving data for index 157 khatanga
# Retrieving data for index 158 vardo
# Retrieving data for index 159 guerrero negro
# Retrieving data for index 160 high level
# Retrieving data for index 161 vanimo
# Retrieving data for index 162 doctor pedro p. pena
# Error retrieving data for doctor pedro p. pena
# Error Code: 404
# Retrieving data for index 163 kieta
# Retrieving data for index 164 broome
# Retrieving data for index 165 hobart
# Retrieving data for index 166 santa isabel do rio negro
# Retrieving data for index 167 saskylakh
# Retrieving data for index 168 norman wells
# Retrieving data for index 169 berea
# Retrieving data for index 170 rundu
# Retrieving data for index 171 nawa
# Retrieving data for index 172 klaksvik
# Retrieving data for index 173 gat
# Retrieving data for index 174 aquiraz
# Retrieving data for index 175 palabuhanratu
# Error retrieving data for palabuhanratu
# Error Code: 404
# Retrieving data for index 176 hukuntsi
# Retrieving data for index 177 venice
# Retrieving data for index 178 akhmeta
# Retrieving data for index 179 bocas del toro
# Retrieving data for index 180 vao
# Retrieving data for index 181 fairbanks
# Retrieving data for index 182 bengkulu
# Error retrieving data for bengkulu
# Error Code: 404
# Retrieving data for index 183 saint-pierre
# Retrieving data for index 184 itarema
# Retrieving data for index 185 puerto ayora
# Retrieving data for index 186 souillac
# Retrieving data for index 187 bedesa
# Retrieving data for index 188 ambon
# Retrieving data for index 189 lolua
# Error retrieving data for lolua
# Error Code: 404
# Retrieving data for index 190 quelimane
# Retrieving data for index 191 fasa
# Retrieving data for index 192 san quintin
# Retrieving data for index 193 atuona
# Retrieving data for index 194 aykhal
# Retrieving data for index 195 hasaki
# Retrieving data for index 196 nikolskoye
# Retrieving data for index 197 hualmay
# Retrieving data for index 198 vyshkov
# Retrieving data for index 199 tokur
# Retrieving data for index 200 kaitangata
# Retrieving data for index 201 beira
# Retrieving data for index 202 totolapa
# Retrieving data for index 203 vila franca do campo
# Retrieving data for index 204 chifeng
# Retrieving data for index 205 praia da vitoria
# Retrieving data for index 206 puerto colombia
# Retrieving data for index 207 san cristobal
# Retrieving data for index 208 eftimie murgu
# Retrieving data for index 209 nishihara
# Retrieving data for index 210 newtonmore
# Retrieving data for index 211 khani
# Retrieving data for index 212 sakakah
# Error retrieving data for sakakah
# Error Code: 404
# Retrieving data for index 213 sentyabrskiy
# Error retrieving data for sentyabrskiy
# Error Code: 404
# Retrieving data for index 214 mitsamiouli
# Retrieving data for index 215 taksimo
# Retrieving data for index 216 kavaratti
# Retrieving data for index 217 lorengau
# Retrieving data for index 218 ribeira grande
# Retrieving data for index 219 saint george
# Retrieving data for index 220 amderma
# Error retrieving data for amderma
# Error Code: 404
# Retrieving data for index 221 farafangana
# Retrieving data for index 222 barentsburg
# Error retrieving data for barentsburg
# Error Code: 404
# Retrieving data for index 223 leningradskiy
# Retrieving data for index 224 marzuq
# Retrieving data for index 225 coro
# Retrieving data for index 226 mbini
# Retrieving data for index 227 general roca
# Retrieving data for index 228 poronaysk
# Retrieving data for index 229 mindelo
# Retrieving data for index 230 tabiauea
# Error retrieving data for tabiauea
# Error Code: 404
# Retrieving data for index 231 pedra branca
# Retrieving data for index 232 los llanos de aridane
# Retrieving data for index 233 sao felix do xingu
# Retrieving data for index 234 paamiut
# Retrieving data for index 235 salalah
# Retrieving data for index 236 upernavik
# Retrieving data for index 237 tilichiki
# Retrieving data for index 238 qaqortoq
# Retrieving data for index 239 lagoa
# Retrieving data for index 240 foam lake
# Retrieving data for index 241 bambous virieux
# Retrieving data for index 242 labytnangi
# Retrieving data for index 243 cayenne
# Retrieving data for index 244 andenes
# Error retrieving data for andenes
# Error Code: 404
# Retrieving data for index 245 attawapiskat
# Error retrieving data for attawapiskat
# Error Code: 404
# Retrieving data for index 246 torbay
# Retrieving data for index 247 meambar
# Error retrieving data for meambar
# Error Code: 404
# Retrieving data for index 248 champerico
# Retrieving data for index 249 tessalit
# Retrieving data for index 250 huejuquilla el alto
# Retrieving data for index 251 eirunepe
# Retrieving data for index 252 cochrane
# Retrieving data for index 253 tome-acu
# Error retrieving data for tome-acu
# Error Code: 404
# Retrieving data for index 254 nome
# Retrieving data for index 255 beringovskiy
# Retrieving data for index 256 juazeiro
# Retrieving data for index 257 alta floresta
# Retrieving data for index 258 camargo
# Retrieving data for index 259 port-cartier
# Retrieving data for index 260 pataias
# Retrieving data for index 261 boditi
# Retrieving data for index 262 kurchum
# Retrieving data for index 263 vestmannaeyjar
# Retrieving data for index 264 nivala
# Retrieving data for index 265 padang
# Retrieving data for index 266 chokurdakh
# Retrieving data for index 267 kurilsk
# Retrieving data for index 268 portland
# Retrieving data for index 269 buluang
# Retrieving data for index 270 vihti
# Retrieving data for index 271 misratah
# Retrieving data for index 272 benguela
# Retrieving data for index 273 itoman
# Retrieving data for index 274 kautokeino
# Retrieving data for index 275 pangnirtung
# Retrieving data for index 276 mantua
# Retrieving data for index 277 utiroa
# Error retrieving data for utiroa
# Error Code: 404
# Retrieving data for index 278 lasa
# Retrieving data for index 279 lingsugur
# Retrieving data for index 280 marawi
# Retrieving data for index 281 high rock
# Retrieving data for index 282 liwale
# Retrieving data for index 283 pierre
# Retrieving data for index 284 vila do maio
# Retrieving data for index 285 mata
# Retrieving data for index 286 oum hadjer
# Retrieving data for index 287 saldanha
# Retrieving data for index 288 susanville
# Retrieving data for index 289 ponta do sol
# Retrieving data for index 290 avera
# Retrieving data for index 291 karpogory
# Retrieving data for index 292 dolbeau
# Error retrieving data for dolbeau
# Error Code: 404
# Retrieving data for index 293 malatya
# Error retrieving data for malatya
# Error Code: 404
# Retrieving data for index 294 geraldton
# Retrieving data for index 295 port-gentil
# Retrieving data for index 296 shush
# Retrieving data for index 297 laguna
# Retrieving data for index 298 vytegra
# Retrieving data for index 299 grand forks
# Retrieving data for index 300 bahia honda
# Retrieving data for index 301 cockburn town
# Retrieving data for index 302 barcelos
# Retrieving data for index 303 hami
# Retrieving data for index 304 mahon
# Retrieving data for index 305 christchurch
# Retrieving data for index 306 igarka
# Retrieving data for index 307 nelson bay
# Retrieving data for index 308 sosnogorsk
# Retrieving data for index 309 dergachi
# Retrieving data for index 310 nainpur
# Retrieving data for index 311 fortuna
# Retrieving data for index 312 tuatapere
# Retrieving data for index 313 ojinaga
# Retrieving data for index 314 dalvik
# Retrieving data for index 315 jobner
# Retrieving data for index 316 almaznyy
# Retrieving data for index 317 saint-francois
# Retrieving data for index 318 farsund
# Retrieving data for index 319 male
# Retrieving data for index 320 port macquarie
# Retrieving data for index 321 glamoc
# Retrieving data for index 322 tiksi
# Retrieving data for index 323 tocache
# Retrieving data for index 324 marsh harbour
# Retrieving data for index 325 neiafu
# Retrieving data for index 326 dekar
# Retrieving data for index 327 sarvar
# Retrieving data for index 328 kenai
# Retrieving data for index 329 bhadasar
# Retrieving data for index 330 taoudenni
# Retrieving data for index 331 gold coast
# Retrieving data for index 332 emba
# Retrieving data for index 333 namatanai
# Retrieving data for index 334 sorochinsk
# Retrieving data for index 335 ryotsu
# Retrieving data for index 336 bowen
# Retrieving data for index 337 bolshoy tsaryn
# Error retrieving data for bolshoy tsaryn
# Error Code: 404
# Retrieving data for index 338 porto-vecchio
# Retrieving data for index 339 namanga
# Retrieving data for index 340 garissa
# Retrieving data for index 341 jutai
# Retrieving data for index 342 yomitan
# Error retrieving data for yomitan
# Error Code: 404
# Retrieving data for index 343 margherita
# Retrieving data for index 344 grand gaube
# Retrieving data for index 345 sioux lookout
# Retrieving data for index 346 cravo norte
# Retrieving data for index 347 deputatskiy
# Retrieving data for index 348 san juan
# Retrieving data for index 349 bawku
# Retrieving data for index 350 abu samrah
# Retrieving data for index 351 camacha
# Retrieving data for index 352 caravelas
# Retrieving data for index 353 namibe
# Retrieving data for index 354 pontes e lacerda
# Retrieving data for index 355 palafrugell
# Retrieving data for index 356 doha
# Retrieving data for index 357 beaufort
# Retrieving data for index 358 kloulklubed
# Retrieving data for index 359 pichucalco
# Retrieving data for index 360 umm kaddadah
# Retrieving data for index 361 korla
# Error retrieving data for korla
# Error Code: 404
# Retrieving data for index 362 ambilobe
# Retrieving data for index 363 altamira
# Retrieving data for index 364 merauke
# Retrieving data for index 365 bubaque
# Retrieving data for index 366 foz
# Retrieving data for index 367 stepnyak
# Retrieving data for index 368 siocon
# Retrieving data for index 369 karaul
# Error retrieving data for karaul
# Error Code: 404
# Retrieving data for index 370 broken hill
# Retrieving data for index 371 srednekolymsk
# Retrieving data for index 372 husavik
# Retrieving data for index 373 dosso
# Retrieving data for index 374 longyearbyen
# Retrieving data for index 375 langsa
# Retrieving data for index 376 cervo
# Retrieving data for index 377 solovetskiy
# Error retrieving data for solovetskiy
# Error Code: 404
# Retrieving data for index 378 ajaccio
# Retrieving data for index 379 santa cruz
# Retrieving data for index 380 zelenoborsk
# Retrieving data for index 381 serpa
# Retrieving data for index 382 dolores
# Retrieving data for index 383 arraial do cabo
# Retrieving data for index 384 tura
# Retrieving data for index 385 berlevag
# Retrieving data for index 386 nouadhibou
# Retrieving data for index 387 zhigansk
# Retrieving data for index 388 koslan
# Retrieving data for index 389 wanning
# Retrieving data for index 390 bud
# Retrieving data for index 391 kirkwood
# Retrieving data for index 392 severo-kurilsk
# Retrieving data for index 393 mehamn
# Retrieving data for index 394 westport
# Retrieving data for index 395 rajampet
# Retrieving data for index 396 anadyr
# Retrieving data for index 397 shenzhen
# Retrieving data for index 398 penzance
# Retrieving data for index 399 staroshcherbinovskaya
# Retrieving data for index 400 vicuna
# Error retrieving data for vicuna
# Error Code: 404
# Retrieving data for index 401 wanaka
# Retrieving data for index 402 shahpur
# Retrieving data for index 403 kolvereid
# Retrieving data for index 404 suao
# Error retrieving data for suao
# Error Code: 404
# Retrieving data for index 405 tecolutilla
# Retrieving data for index 406 tigre
# Retrieving data for index 407 denpasar
# Retrieving data for index 408 katsuura
# Retrieving data for index 409 belyy yar
# Retrieving data for index 410 fort nelson
# Retrieving data for index 411 candolim
# Retrieving data for index 412 oussouye
# Retrieving data for index 413 rybachiy
# Retrieving data for index 414 luwuk
# Retrieving data for index 415 bojnurd
# Retrieving data for index 416 dingle
# Retrieving data for index 417 mount gambier
# Retrieving data for index 418 chuy
# Retrieving data for index 419 severobaykalsk
# Retrieving data for index 420 holme
# Retrieving data for index 421 gigmoto
# Retrieving data for index 422 floro
# Retrieving data for index 423 hamilton
# Retrieving data for index 424 springbok
# Retrieving data for index 425 tarbagatay
# Retrieving data for index 426 kushiro
# Retrieving data for index 427 koumac
# Retrieving data for index 428 prince rupert
# Retrieving data for index 429 wanlaweyn
# Retrieving data for index 430 port blair
# Retrieving data for index 431 olafsvik
# Error retrieving data for olafsvik
# Error Code: 404
# Retrieving data for index 432 bargal
# Error retrieving data for bargal
# Error Code: 404
# Retrieving data for index 433 ponta delgada
# Retrieving data for index 434 krasnoyarsk-66
# Error retrieving data for krasnoyarsk-66
# Error Code: 404
# Retrieving data for index 435 sainte-maxime
# Retrieving data for index 436 daru
# Retrieving data for index 437 huangnihe
# Retrieving data for index 438 kaiyuan
# Retrieving data for index 439 walvis bay
# Retrieving data for index 440 shihezi
# Retrieving data for index 441 guararapes
# Retrieving data for index 442 lobito
# Retrieving data for index 443 manicore
# Retrieving data for index 444 santa maria del oro
# Retrieving data for index 445 kayes
# Retrieving data for index 446 deh rawud
# Error retrieving data for deh rawud
# Error Code: 404
# Retrieving data for index 447 ust-maya
# Retrieving data for index 448 adrar
# Retrieving data for index 449 san andres
# Retrieving data for index 450 bathsheba
# Retrieving data for index 451 sorong
# Retrieving data for index 452 ishigaki
# Retrieving data for index 453 tefe
# Retrieving data for index 454 halifax
# Retrieving data for index 455 nemuro
# Retrieving data for index 456 voh
# Retrieving data for index 457 vila velha
# Retrieving data for index 458 sola
# Retrieving data for index 459 urumqi
# Error retrieving data for urumqi
# Error Code: 404
# Retrieving data for index 460 haines junction
# Retrieving data for index 461 luderitz
# Retrieving data for index 462 nylstroom
# Error retrieving data for nylstroom
# Error Code: 404
# Retrieving data for index 463 muscatine
# Retrieving data for index 464 tazovskiy
# Retrieving data for index 465 chumikan
# Retrieving data for index 466 mayo
# Retrieving data for index 467 bumba
# Retrieving data for index 468 sorvag
# Error retrieving data for sorvag
# Error Code: 404
# Retrieving data for index 469 orangeville
# Retrieving data for index 470 najran
# Retrieving data for index 471 newport
# Retrieving data for index 472 hay river
# Retrieving data for index 473 buchanan
# Retrieving data for index 474 naro
# Retrieving data for index 475 biltine
# Retrieving data for index 476 kayerkan
# Retrieving data for index 477 marcona
# Error retrieving data for marcona
# Error Code: 404
# Retrieving data for index 478 jamiltepec
# Error retrieving data for jamiltepec
# Error Code: 404
# Retrieving data for index 479 bilma
# Retrieving data for index 480 karratha
# Retrieving data for index 481 general artigas
# Retrieving data for index 482 waipawa
# Retrieving data for index 483 alice springs
# Retrieving data for index 484 ovsyanka
# Retrieving data for index 485 sokolo
# Retrieving data for index 486 nueva guinea
# Retrieving data for index 487 shache
# Retrieving data for index 488 ferme-neuve
# Retrieving data for index 489 comodoro rivadavia
# Retrieving data for index 490 sungaipenuh
# Retrieving data for index 491 ketchikan
# Retrieving data for index 492 gizo
# Retrieving data for index 493 vredendal
# Retrieving data for index 494 viligili
# Error retrieving data for viligili
# Error Code: 404
# Retrieving data for index 495 taltal
# Retrieving data for index 496 paoua
# Retrieving data for index 497 kurduvadi
# Retrieving data for index 498 ashcroft
# Retrieving data for index 499 panama city
# Retrieving data for index 500 paita
# Retrieving data for index 501 kidal
# Retrieving data for index 502 den helder
# Retrieving data for index 503 boysun
# Retrieving data for index 504 rantepao
# Retrieving data for index 505 panjab
# Retrieving data for index 506 tucurui
# Retrieving data for index 507 helong
# Retrieving data for index 508 mikhaylovka
# Retrieving data for index 509 khorixas
# Retrieving data for index 510 barauna
# Retrieving data for index 511 te anau
# Retrieving data for index 512 karkaralinsk
# Error retrieving data for karkaralinsk
# Error Code: 404
# Retrieving data for index 513 cascais
# Retrieving data for index 514 kijang
# Retrieving data for index 515 vagur
# Retrieving data for index 516 kaabong
# Retrieving data for index 517 villamontes
# Retrieving data for index 518 samarai
# Retrieving data for index 519 natal
# Retrieving data for index 520 tupik
# Retrieving data for index 521 kem
# Retrieving data for index 522 starokostyantyniv
# Error retrieving data for starokostyantyniv
# Error Code: 200
# Retrieving data for index 523 riverton
# Retrieving data for index 524 quang ngai
# Retrieving data for index 525 boyolangu
# Retrieving data for index 526 camiri
# Retrieving data for index 527 makakilo city
# Retrieving data for index 528 rio gallegos
# Retrieving data for index 529 inhambane
# Retrieving data for index 530 oparino
# Retrieving data for index 531 verkhnevilyuysk
# Retrieving data for index 532 saint-joseph
# Retrieving data for index 533 hoquiam
# Retrieving data for index 534 karagay
# Retrieving data for index 535 beidao
# Retrieving data for index 536 hjelset
# Retrieving data for index 537 pitsunda
# Retrieving data for index 538 ramganj mandi
# Retrieving data for index 539 dujuma
# Error retrieving data for dujuma
# Error Code: 404
# Retrieving data for index 540 komsomolsk
# Retrieving data for index 541 antalaha
# Retrieving data for index 542 yialos
# Error retrieving data for yialos
# Error Code: 404
# Retrieving data for index 543 faanui
# Retrieving data for index 544 kalmunai
# Retrieving data for index 545 tabou
# Retrieving data for index 546 palamos
# Retrieving data for index 547 beyla
# Retrieving data for index 548 alofi
# Retrieving data for index 549 leninogorsk
# Retrieving data for index 550 sinnamary
# Retrieving data for index 551 cheyenne
# Retrieving data for index 552 portree
# Retrieving data for index 553 andevoranto
# Error retrieving data for andevoranto
# Error Code: 404
# Retrieving data for index 554 alugan
# Retrieving data for index 555 stillwater
# Retrieving data for index 556 beroroha
# Retrieving data for index 557 okhotsk
# Retrieving data for index 558 kaupanger
# Retrieving data for index 559 ayan
# Retrieving data for index 560 krasnoselkup
# Error retrieving data for krasnoselkup
# Error Code: 404
# Retrieving data for index 561 mackay
# Retrieving data for index 562 doume
# Error retrieving data for doume
# Error Code: 404
# Retrieving data for index 563 awjilah
# Retrieving data for index 564 acarau
# Error retrieving data for acarau
# Error Code: 404
# Retrieving data for index 565 juneau
# Retrieving data for index 566 touros
# Retrieving data for index 567 sangar
# Retrieving data for index 568 hobyo
# Retrieving data for index 569 zhanaozen
# Retrieving data for index 570 kampot
# Retrieving data for index 571 acapulco
# Retrieving data for index 572 prigorodnyy
# Retrieving data for index 573 tiznit
# Retrieving data for index 574 hambantota
# Retrieving data for index 575 maldonado
# Retrieving data for index 576 tricase
# Retrieving data for index 577 pemba
# Retrieving data for index 578 tongren
# Retrieving data for index 579 arima
# Retrieving data for index 580 san carlos de bariloche
# Retrieving data for index 581 kyren
# Retrieving data for index 582 pangoa
# Retrieving data for index 583 ban dung
# Retrieving data for index 584 krasnoyarsk
# Retrieving data for index 585 lata
# Retrieving data for index 586 araouane
# Retrieving data for index 587 sorland
# Retrieving data for index 588 mabaruma
# Retrieving data for index 589 yankton
# Retrieving data for index 590 tallahassee
# Retrieving data for index 591 huarmey
# Retrieving data for index 592 jiuquan
# Retrieving data for index 593 atasu
# Retrieving data for index 594 riyadh
# Retrieving data for index 595 mtsamboro
# Retrieving data for index 596 yumen
# Retrieving data for index 597 kondoa
# Retrieving data for index 598 tarauaca
# Retrieving data for index 599 anahuac
# Retrieving data for index 600 mugumu
# Retrieving data for index 601 zlobin
# Retrieving data for index 602 luanda
# Retrieving data for index 603 luangwa
# Retrieving data for index 604 bafq
# Retrieving data for index 605 gondanglegi
# Retrieving data for index 606 vanavara
# Retrieving data for index 607 petropavlovsk-kamchatskiy
# Retrieving data for index 608 murchison
# Retrieving data for index 609 ugep
# Retrieving data for index 610 mendi
# Retrieving data for index 611 kudahuvadhoo
# Retrieving data for index 612 half moon bay
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 37.46, 'lon': -122.43},
#  'dt': 1554397562,
#  'id': 5354943,
#  'main': {'humidity': 71,
#           'pressure': 1017,
#           'temp': 13.53,
#           'temp_max': 15,
#           'temp_min': 11.67},
#  'name': 'Half Moon Bay',
#  'sys': {'country': 'US',
#          'id': 5903,
#          'message': 0.0126,
#          'sunrise': 1554385843,
#          'sunset': 1554431660,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 150, 'speed': 3.1}}
# Data Retrieval Complete....
# ---------------------------------------------------------
# Number of cities weather data  not found: 61

# %%
print(len(city_list))
print(len(cloudiness))
print(len(country))
print(len(date))
print(len(humidity))
print(len(lat))
print(len(lng))
print(len(MaxTemp))
print(len(WindSpeed))
# Out:
# 551
# 551
# 551
# 551
# 551
# 551
# 551
# 551
# 551

# %%
#Store all responses into a DataFrame 

weather_df = pd.DataFrame ({
    "City": city_list,
    "Cloudiness": cloudiness,
    "Country_code": country,
    "Date": date,
    "Humidity": humidity,
    "Latitude": lat,
    "Longitude": lng,
    "Max Temp": MaxTemp,
    "Wind Speed": WindSpeed
})

weather_df.head()
# Out:
#             City  Cloudiness Country_code        Date  Humidity  Latitude  \
# 0           Lebu          92           ET  1554397531        66      8.96
# 1  Mar del Plata           0           AR  1554397531        42    -46.43
# 2         Dikson          76           RU  1554397531        98     73.51
# 3         Avarua          44           CK  1554395400       100    -21.21
# 4      Carnarvon          64           ZA  1554397531        28    -30.97
#
#    Longitude  Max Temp  Wind Speed
# 0      38.73     15.51        1.72
# 1     -67.52     17.96        8.97
# 2      80.55     -6.44        4.52
# 3    -159.78     21.00        1.00
# 4      22.13     18.26        5.67
